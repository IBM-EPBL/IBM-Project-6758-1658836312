# %%
# !conda install --yes keras
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\HARIHARAN\anaconda3
#
#   added / updated specs:
#     - keras
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     keras-2.6.0                |     pyhd3eb1b0_0         721 KB
#     ------------------------------------------------------------
#                                            Total:         721 KB
#
# The following NEW packages will be INSTALLED:
#
#   keras              pkgs/main/noarch::keras-2.6.0-pyhd3eb1b0_0 None
#
#
#
# Downloading and Extracting Packages
#
# keras-2.6.0          | 721 KB    |            |   0%
# keras-2.6.0          | 721 KB    | #####1     |  51%
# keras-2.6.0          | 721 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done

# %%
# !conda install --yes tensorflow
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\HARIHARAN\anaconda3
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _tflow_select-2.3.0        |              mkl           3 KB
#     abseil-cpp-20211102.0      |       hd77b12b_0         1.7 MB
#     absl-py-1.3.0              |   py39haa95532_0         171 KB
#     aiohttp-3.8.1              |   py39h2bbff1b_1         496 KB
#     aiosignal-1.2.0            |     pyhd3eb1b0_0          12 KB
#     anaconda-2022.10           |          py310_0          13 KB
#     astunparse-1.6.3           |             py_0          17 KB
#     async-timeout-4.0.2        |   py39haa95532_0          12 KB
#     blinker-1.4                |   py39haa95532_0          23 KB
#     ca-certificates-2022.10.11 |       haa95532_0         125 KB
#     cachetools-4.2.2           |     pyhd3eb1b0_0          13 KB
#     certifi-2022.9.24          |   py39haa95532_0         154 KB
#     flatbuffers-2.0.0          |       h6c2663c_0         1.4 MB
#     frozenlist-1.2.0           |   py39h2bbff1b_0          77 KB
#     gast-0.5.3                 |     pyhd3eb1b0_0          21 KB
#     google-auth-2.6.0          |     pyhd3eb1b0_0          83 KB
#     google-auth-oauthlib-0.4.4 |     pyhd3eb1b0_0          18 KB
#     google-pasta-0.2.0         |     pyhd3eb1b0_0          46 KB
#     grpcio-1.42.0              |   py39hc60d5dd_0         1.9 MB
#     keras-2.9.0                |   py39haa95532_0         1.5 MB
#     keras-preprocessing-1.1.2  |     pyhd3eb1b0_0          35 KB
#     libprotobuf-3.20.1         |       h23ce68f_0         2.0 MB
#     multidict-6.0.2            |   py39h2bbff1b_0          46 KB
#     oauthlib-3.2.1             |   py39haa95532_0         194 KB
#     openssl-1.1.1s             |       h2bbff1b_0         5.5 MB
#     opt_einsum-3.3.0           |     pyhd3eb1b0_1          57 KB
#     protobuf-3.20.1            |   py39hd77b12b_0         231 KB
#     python-flatbuffers-2.0     |     pyhd3eb1b0_0          34 KB
#     requests-oauthlib-1.3.0    |             py_0          23 KB
#     rsa-4.7.2                  |     pyhd3eb1b0_1          28 KB
#     scipy-1.7.3                |   py39h7a0a035_2        13.9 MB
#     tensorboard-2.9.0          |   py39haa95532_0         5.5 MB
#     tensorboard-data-server-0.6.0|   py39haa95532_0          17 KB
#     tensorboard-plugin-wit-1.8.1|   py39haa95532_0         671 KB
#     tensorflow-2.9.1           |mkl_py39hc9ebea8_1           4 KB
#     tensorflow-base-2.9.1      |mkl_py39h6a7f48e_1        73.3 MB
#     tensorflow-estimator-2.9.0 |   py39haa95532_0         491 KB
#     termcolor-1.1.0            |   py39haa95532_1           9 KB
#     yarl-1.8.1                 |   py39h2bbff1b_0          80 KB
#     ------------------------------------------------------------
#                                            Total:       109.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   _tflow_select      pkgs/main/win-64::_tflow_select-2.3.0-mkl None
#   abseil-cpp         pkgs/main/win-64::abseil-cpp-20211102.0-hd77b12b_0 None
#   absl-py            pkgs/main/win-64::absl-py-1.3.0-py39haa95532_0 None
#   aiohttp            pkgs/main/win-64::aiohttp-3.8.1-py39h2bbff1b_1 None
#   aiosignal          pkgs/main/noarch::aiosignal-1.2.0-pyhd3eb1b0_0 None
#   astunparse         pkgs/main/noarch::astunparse-1.6.3-py_0 None
#   async-timeout      pkgs/main/win-64::async-timeout-4.0.2-py39haa95532_0 None
#   blinker            pkgs/main/win-64::blinker-1.4-py39haa95532_0 None
#   cachetools         pkgs/main/noarch::cachetools-4.2.2-pyhd3eb1b0_0 None
#   flatbuffers        pkgs/main/win-64::flatbuffers-2.0.0-h6c2663c_0 None
#   frozenlist         pkgs/main/win-64::frozenlist-1.2.0-py39h2bbff1b_0 None
#   gast               pkgs/main/noarch::gast-0.5.3-pyhd3eb1b0_0 None
#   google-auth        pkgs/main/noarch::google-auth-2.6.0-pyhd3eb1b0_0 None
#   google-auth-oauth~ pkgs/main/noarch::google-auth-oauthlib-0.4.4-pyhd3eb1b0_0 None
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-pyhd3eb1b0_0 None
#   grpcio             pkgs/main/win-64::grpcio-1.42.0-py39hc60d5dd_0 None
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.2-pyhd3eb1b0_0 None
#   libprotobuf        pkgs/main/win-64::libprotobuf-3.20.1-h23ce68f_0 None
#   multidict          pkgs/main/win-64::multidict-6.0.2-py39h2bbff1b_0 None
#   oauthlib           pkgs/main/win-64::oauthlib-3.2.1-py39haa95532_0 None
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.3.0-pyhd3eb1b0_1 None
#   protobuf           pkgs/main/win-64::protobuf-3.20.1-py39hd77b12b_0 None
#   python-flatbuffers pkgs/main/noarch::python-flatbuffers-2.0-pyhd3eb1b0_0 None
#   requests-oauthlib  pkgs/main/noarch::requests-oauthlib-1.3.0-py_0 None
#   rsa                pkgs/main/noarch::rsa-4.7.2-pyhd3eb1b0_1 None
#   tensorboard        pkgs/main/win-64::tensorboard-2.9.0-py39haa95532_0 None
#   tensorboard-data-~ pkgs/main/win-64::tensorboard-data-server-0.6.0-py39haa95532_0 None
#   tensorboard-plugi~ pkgs/main/win-64::tensorboard-plugin-wit-1.8.1-py39haa95532_0 None
#   tensorflow         pkgs/main/win-64::tensorflow-2.9.1-mkl_py39hc9ebea8_1 None
#   tensorflow-base    pkgs/main/win-64::tensorflow-base-2.9.1-mkl_py39h6a7f48e_1 None
#   tensorflow-estima~ pkgs/main/win-64::tensorflow-estimator-2.9.0-py39haa95532_0 None
#   termcolor          pkgs/main/win-64::termcolor-1.1.0-py39haa95532_1 None
#   yarl               pkgs/main/win-64::yarl-1.8.1-py39h2bbff1b_0 None
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2022.07.19-haa95532_0 --> 2022.10.11-haa95532_0 None
#   certifi                          2022.9.14-py39haa95532_0 --> 2022.9.24-py39haa95532_0 None
#   keras              pkgs/main/noarch::keras-2.6.0-pyhd3eb~ --> pkgs/main/win-64::keras-2.9.0-py39haa95532_0 None
#   openssl                                 1.1.1q-h2bbff1b_0 --> 1.1.1s-h2bbff1b_0 None
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2022.10-py39_0 --> 2022.10-py310_0 None
#   scipy                                1.9.1-py39he11b74f_0 --> 1.7.3-py39h7a0a035_2 None
#
#
#
# Downloading and Extracting Packages
#
# aiosignal-1.2.0      | 12 KB     |            |   0%
# aiosignal-1.2.0      | 12 KB     | ########## | 100%
# aiosignal-1.2.0      | 12 KB     | ########## | 100%
#
# requests-oauthlib-1. | 23 KB     |            |   0%
# requests-oauthlib-1. | 23 KB     | ########## | 100%
#
# ca-certificates-2022 | 125 KB    |            |   0%
# ca-certificates-2022 | 125 KB    | ########## | 100%
#
# tensorboard-plugin-w | 671 KB    |            |   0%
# tensorboard-plugin-w | 671 KB    | #####7     |  57%
# tensorboard-plugin-w | 671 KB    | ########## | 100%
#
# google-auth-oauthlib | 18 KB     |            |   0%
# google-auth-oauthlib | 18 KB     | ########## | 100%
#
# abseil-cpp-20211102. | 1.7 MB    |            |   0%
# abseil-cpp-20211102. | 1.7 MB    | ##2        |  23%
# abseil-cpp-20211102. | 1.7 MB    | #####4     |  55%
# abseil-cpp-20211102. | 1.7 MB    | ########2  |  83%
# abseil-cpp-20211102. | 1.7 MB    | ########## | 100%
#
# tensorflow-estimator | 491 KB    |            |   0%
# tensorflow-estimator | 491 KB    | ####8      |  49%
# tensorflow-estimator | 491 KB    | ########## | 100%
# tensorflow-estimator | 491 KB    | ########## | 100%
#
# keras-2.9.0          | 1.5 MB    |            |   0%
# keras-2.9.0          | 1.5 MB    | #8         |  18%
# keras-2.9.0          | 1.5 MB    | ####8      |  48%
# keras-2.9.0          | 1.5 MB    | #######2   |  73%
# keras-2.9.0          | 1.5 MB    | #########7 |  97%
# keras-2.9.0          | 1.5 MB    | ########## | 100%
#
# _tflow_select-2.3.0  | 3 KB      |            |   0%
# _tflow_select-2.3.0  | 3 KB      | ########## | 100%
#
# openssl-1.1.1s       | 5.5 MB    |            |   0%
# openssl-1.1.1s       | 5.5 MB    | 6          |   7%
# openssl-1.1.1s       | 5.5 MB    | #5         |  15%
# openssl-1.1.1s       | 5.5 MB    | ##3        |  24%
# openssl-1.1.1s       | 5.5 MB    | ###3       |  33%
# openssl-1.1.1s       | 5.5 MB    | ####1      |  42%
# openssl-1.1.1s       | 5.5 MB    | ####9      |  50%
# openssl-1.1.1s       | 5.5 MB    | #####6     |  57%
# openssl-1.1.1s       | 5.5 MB    | ######7    |  67%
# openssl-1.1.1s       | 5.5 MB    | #######6   |  76%
# openssl-1.1.1s       | 5.5 MB    | ########4  |  85%
# openssl-1.1.1s       | 5.5 MB    | #########4 |  94%
# openssl-1.1.1s       | 5.5 MB    | ########## | 100%
#
# blinker-1.4          | 23 KB     |            |   0%
# blinker-1.4          | 23 KB     | ########## | 100%
#
# grpcio-1.42.0        | 1.9 MB    |            |   0%
# grpcio-1.42.0        | 1.9 MB    | #6         |  17%
# grpcio-1.42.0        | 1.9 MB    | ###6       |  36%
# grpcio-1.42.0        | 1.9 MB    | ######     |  61%
# grpcio-1.42.0        | 1.9 MB    | ########6  |  86%
# grpcio-1.42.0        | 1.9 MB    | ########## | 100%
#
# opt_einsum-3.3.0     | 57 KB     |            |   0%
# opt_einsum-3.3.0     | 57 KB     | ########## | 100%
#
# tensorboard-2.9.0    | 5.5 MB    |            |   0%
# tensorboard-2.9.0    | 5.5 MB    | 3          |   4%
# tensorboard-2.9.0    | 5.5 MB    | #3         |  14%
# tensorboard-2.9.0    | 5.5 MB    | ##1        |  22%
# tensorboard-2.9.0    | 5.5 MB    | ##9        |  29%
# tensorboard-2.9.0    | 5.5 MB    | ###9       |  39%
# tensorboard-2.9.0    | 5.5 MB    | ####7      |  48%
# tensorboard-2.9.0    | 5.5 MB    | #####5     |  56%
# tensorboard-2.9.0    | 5.5 MB    | ######4    |  64%
# tensorboard-2.9.0    | 5.5 MB    | #######2   |  72%
# tensorboard-2.9.0    | 5.5 MB    | ########1  |  81%
# tensorboard-2.9.0    | 5.5 MB    | #########1 |  92%
# tensorboard-2.9.0    | 5.5 MB    | ########## | 100%
#
# flatbuffers-2.0.0    | 1.4 MB    |            |   0%
# flatbuffers-2.0.0    | 1.4 MB    | ##1        |  21%
# flatbuffers-2.0.0    | 1.4 MB    | #####      |  51%
# flatbuffers-2.0.0    | 1.4 MB    | #########6 |  97%
# flatbuffers-2.0.0    | 1.4 MB    | ########## | 100%
#
# python-flatbuffers-2 | 34 KB     |            |   0%
# python-flatbuffers-2 | 34 KB     | ########## | 100%
#
# google-pasta-0.2.0   | 46 KB     |            |   0%
# google-pasta-0.2.0   | 46 KB     | ########## | 100%
#
# aiohttp-3.8.1        | 496 KB    |            |   0%
# aiohttp-3.8.1        | 496 KB    | #######4   |  74%
# aiohttp-3.8.1        | 496 KB    | ########## | 100%
#
# gast-0.5.3           | 21 KB     |            |   0%
# gast-0.5.3           | 21 KB     | ########## | 100%
#
# rsa-4.7.2            | 28 KB     |            |   0%
# rsa-4.7.2            | 28 KB     | ########## | 100%
#
# async-timeout-4.0.2  | 12 KB     |            |   0%
# async-timeout-4.0.2  | 12 KB     | ########## | 100%
#
# astunparse-1.6.3     | 17 KB     |            |   0%
# astunparse-1.6.3     | 17 KB     | ########## | 100%
#
# multidict-6.0.2      | 46 KB     |            |   0%
# multidict-6.0.2      | 46 KB     | ########## | 100%
#
# protobuf-3.20.1      | 231 KB    |            |   0%
# protobuf-3.20.1      | 231 KB    | ########## | 100%
# protobuf-3.20.1      | 231 KB    | ########## | 100%
#
# frozenlist-1.2.0     | 77 KB     |            |   0%
# frozenlist-1.2.0     | 77 KB     | ########## | 100%
#
# anaconda-2022.10     | 13 KB     |            |   0%
# anaconda-2022.10     | 13 KB     | ########## | 100%
#
# tensorflow-2.9.1     | 4 KB      |            |   0%
# tensorflow-2.9.1     | 4 KB      | ########## | 100%
#
# libprotobuf-3.20.1   | 2.0 MB    |            |   0%
# libprotobuf-3.20.1   | 2.0 MB    | #8         |  18%
# libprotobuf-3.20.1   | 2.0 MB    | ####1      |  41%
# libprotobuf-3.20.1   | 2.0 MB    | #######2   |  72%
# libprotobuf-3.20.1   | 2.0 MB    | #########7 |  97%
# libprotobuf-3.20.1   | 2.0 MB    | ########## | 100%
#
# keras-preprocessing- | 35 KB     |            |   0%
# keras-preprocessing- | 35 KB     | ########## | 100%
#
# tensorboard-data-ser | 17 KB     |            |   0%
# tensorboard-data-ser | 17 KB     | ########## | 100%
#
# tensorflow-base-2.9. | 73.3 MB   |            |   0%
# tensorflow-base-2.9. | 73.3 MB   |            |   0%
# tensorflow-base-2.9. | 73.3 MB   | 1          |   1%
# tensorflow-base-2.9. | 73.3 MB   | 1          |   2%
# tensorflow-base-2.9. | 73.3 MB   | 2          |   3%
# tensorflow-base-2.9. | 73.3 MB   | 3          |   3%
# tensorflow-base-2.9. | 73.3 MB   | 3          |   4%
# tensorflow-base-2.9. | 73.3 MB   | 4          |   5%
# tensorflow-base-2.9. | 73.3 MB   | 5          |   5%
# tensorflow-base-2.9. | 73.3 MB   | 5          |   6%
# tensorflow-base-2.9. | 73.3 MB   | 6          |   6%
# tensorflow-base-2.9. | 73.3 MB   | 6          |   7%
# tensorflow-base-2.9. | 73.3 MB   | 7          |   8%
# tensorflow-base-2.9. | 73.3 MB   | 8          |   8%
# tensorflow-base-2.9. | 73.3 MB   | 8          |   9%
# tensorflow-base-2.9. | 73.3 MB   | 9          |  10%
# tensorflow-base-2.9. | 73.3 MB   | #          |  10%
# tensorflow-base-2.9. | 73.3 MB   | #          |  11%
# tensorflow-base-2.9. | 73.3 MB   | #1         |  12%
# tensorflow-base-2.9. | 73.3 MB   | #2         |  12%
# tensorflow-base-2.9. | 73.3 MB   | #2         |  13%
# tensorflow-base-2.9. | 73.3 MB   | #3         |  14%
# tensorflow-base-2.9. | 73.3 MB   | #4         |  14%
# tensorflow-base-2.9. | 73.3 MB   | #4         |  15%
# tensorflow-base-2.9. | 73.3 MB   | #5         |  16%
# tensorflow-base-2.9. | 73.3 MB   | #6         |  16%
# tensorflow-base-2.9. | 73.3 MB   | #6         |  17%
# tensorflow-base-2.9. | 73.3 MB   | #7         |  17%
# tensorflow-base-2.9. | 73.3 MB   | #8         |  18%
# tensorflow-base-2.9. | 73.3 MB   | #8         |  19%
# tensorflow-base-2.9. | 73.3 MB   | #9         |  20%
# tensorflow-base-2.9. | 73.3 MB   | ##         |  20%
# tensorflow-base-2.9. | 73.3 MB   | ##1        |  21%
# tensorflow-base-2.9. | 73.3 MB   | ##1        |  22%
# tensorflow-base-2.9. | 73.3 MB   | ##2        |  23%
# tensorflow-base-2.9. | 73.3 MB   | ##3        |  23%
# tensorflow-base-2.9. | 73.3 MB   | ##4        |  24%
# tensorflow-base-2.9. | 73.3 MB   | ##4        |  25%
# tensorflow-base-2.9. | 73.3 MB   | ##5        |  25%
# tensorflow-base-2.9. | 73.3 MB   | ##6        |  26%
# tensorflow-base-2.9. | 73.3 MB   | ##7        |  27%
# tensorflow-base-2.9. | 73.3 MB   | ##7        |  28%
# tensorflow-base-2.9. | 73.3 MB   | ##8        |  29%
# tensorflow-base-2.9. | 73.3 MB   | ##9        |  30%
# tensorflow-base-2.9. | 73.3 MB   | ###        |  30%
# tensorflow-base-2.9. | 73.3 MB   | ###1       |  31%
# tensorflow-base-2.9. | 73.3 MB   | ###1       |  32%
# tensorflow-base-2.9. | 73.3 MB   | ###2       |  33%
# tensorflow-base-2.9. | 73.3 MB   | ###3       |  33%
# tensorflow-base-2.9. | 73.3 MB   | ###4       |  34%
# tensorflow-base-2.9. | 73.3 MB   | ###4       |  35%
# tensorflow-base-2.9. | 73.3 MB   | ###5       |  36%
# tensorflow-base-2.9. | 73.3 MB   | ###6       |  36%
# tensorflow-base-2.9. | 73.3 MB   | ###7       |  37%
# tensorflow-base-2.9. | 73.3 MB   | ###7       |  38%
# tensorflow-base-2.9. | 73.3 MB   | ###8       |  39%
# tensorflow-base-2.9. | 73.3 MB   | ###9       |  39%
# tensorflow-base-2.9. | 73.3 MB   | ###9       |  40%
# tensorflow-base-2.9. | 73.3 MB   | ####       |  41%
# tensorflow-base-2.9. | 73.3 MB   | ####1      |  41%
# tensorflow-base-2.9. | 73.3 MB   | ####1      |  42%
# tensorflow-base-2.9. | 73.3 MB   | ####2      |  43%
# tensorflow-base-2.9. | 73.3 MB   | ####3      |  43%
# tensorflow-base-2.9. | 73.3 MB   | ####3      |  44%
# tensorflow-base-2.9. | 73.3 MB   | ####4      |  45%
# tensorflow-base-2.9. | 73.3 MB   | ####5      |  45%
# tensorflow-base-2.9. | 73.3 MB   | ####6      |  46%
# tensorflow-base-2.9. | 73.3 MB   | ####6      |  47%
# tensorflow-base-2.9. | 73.3 MB   | ####7      |  48%
# tensorflow-base-2.9. | 73.3 MB   | ####8      |  48%
# tensorflow-base-2.9. | 73.3 MB   | ####9      |  49%
# tensorflow-base-2.9. | 73.3 MB   | #####      |  50%
# tensorflow-base-2.9. | 73.3 MB   | #####      |  51%
# tensorflow-base-2.9. | 73.3 MB   | #####1     |  52%
# tensorflow-base-2.9. | 73.3 MB   | #####2     |  52%
# tensorflow-base-2.9. | 73.3 MB   | #####3     |  53%
# tensorflow-base-2.9. | 73.3 MB   | #####3     |  54%
# tensorflow-base-2.9. | 73.3 MB   | #####4     |  54%
# tensorflow-base-2.9. | 73.3 MB   | #####5     |  55%
# tensorflow-base-2.9. | 73.3 MB   | #####6     |  56%
# tensorflow-base-2.9. | 73.3 MB   | #####6     |  57%
# tensorflow-base-2.9. | 73.3 MB   | #####7     |  57%
# tensorflow-base-2.9. | 73.3 MB   | #####8     |  58%
# tensorflow-base-2.9. | 73.3 MB   | #####8     |  59%
# tensorflow-base-2.9. | 73.3 MB   | #####9     |  60%
# tensorflow-base-2.9. | 73.3 MB   | ######     |  60%
# tensorflow-base-2.9. | 73.3 MB   | ######     |  61%
# tensorflow-base-2.9. | 73.3 MB   | ######1    |  61%
# tensorflow-base-2.9. | 73.3 MB   | ######1    |  62%
# tensorflow-base-2.9. | 73.3 MB   | ######2    |  63%
# tensorflow-base-2.9. | 73.3 MB   | ######3    |  63%
# tensorflow-base-2.9. | 73.3 MB   | ######4    |  64%
# tensorflow-base-2.9. | 73.3 MB   | ######4    |  65%
# tensorflow-base-2.9. | 73.3 MB   | ######5    |  66%
# tensorflow-base-2.9. | 73.3 MB   | ######6    |  66%
# tensorflow-base-2.9. | 73.3 MB   | ######7    |  67%
# tensorflow-base-2.9. | 73.3 MB   | ######7    |  68%
# tensorflow-base-2.9. | 73.3 MB   | ######8    |  68%
# tensorflow-base-2.9. | 73.3 MB   | ######8    |  69%
# tensorflow-base-2.9. | 73.3 MB   | ######9    |  70%
# tensorflow-base-2.9. | 73.3 MB   | #######    |  70%
# tensorflow-base-2.9. | 73.3 MB   | #######    |  71%
# tensorflow-base-2.9. | 73.3 MB   | #######1   |  72%
# tensorflow-base-2.9. | 73.3 MB   | #######2   |  73%
# tensorflow-base-2.9. | 73.3 MB   | #######3   |  73%
# tensorflow-base-2.9. | 73.3 MB   | #######4   |  74%
# tensorflow-base-2.9. | 73.3 MB   | #######4   |  75%
# tensorflow-base-2.9. | 73.3 MB   | #######5   |  76%
# tensorflow-base-2.9. | 73.3 MB   | #######6   |  76%
# tensorflow-base-2.9. | 73.3 MB   | #######6   |  77%
# tensorflow-base-2.9. | 73.3 MB   | #######7   |  78%
# tensorflow-base-2.9. | 73.3 MB   | #######8   |  78%
# tensorflow-base-2.9. | 73.3 MB   | #######9   |  79%
# tensorflow-base-2.9. | 73.3 MB   | #######9   |  80%
# tensorflow-base-2.9. | 73.3 MB   | ########   |  81%
# tensorflow-base-2.9. | 73.3 MB   | ########1  |  81%
# tensorflow-base-2.9. | 73.3 MB   | ########2  |  82%
# tensorflow-base-2.9. | 73.3 MB   | ########2  |  83%
# tensorflow-base-2.9. | 73.3 MB   | ########3  |  84%
# tensorflow-base-2.9. | 73.3 MB   | ########4  |  84%
# tensorflow-base-2.9. | 73.3 MB   | ########4  |  85%
# tensorflow-base-2.9. | 73.3 MB   | ########5  |  86%
# tensorflow-base-2.9. | 73.3 MB   | ########6  |  86%
# tensorflow-base-2.9. | 73.3 MB   | ########7  |  87%
# tensorflow-base-2.9. | 73.3 MB   | ########7  |  88%
# tensorflow-base-2.9. | 73.3 MB   | ########8  |  89%
# tensorflow-base-2.9. | 73.3 MB   | ########9  |  89%
# tensorflow-base-2.9. | 73.3 MB   | ########9  |  90%
# tensorflow-base-2.9. | 73.3 MB   | #########  |  91%
# tensorflow-base-2.9. | 73.3 MB   | #########1 |  91%
# tensorflow-base-2.9. | 73.3 MB   | #########1 |  92%
# tensorflow-base-2.9. | 73.3 MB   | #########2 |  93%
# tensorflow-base-2.9. | 73.3 MB   | #########3 |  93%
# tensorflow-base-2.9. | 73.3 MB   | #########3 |  94%
# tensorflow-base-2.9. | 73.3 MB   | #########4 |  95%
# tensorflow-base-2.9. | 73.3 MB   | #########5 |  95%
# tensorflow-base-2.9. | 73.3 MB   | #########5 |  96%
# tensorflow-base-2.9. | 73.3 MB   | #########6 |  96%
# tensorflow-base-2.9. | 73.3 MB   | #########7 |  97%
# tensorflow-base-2.9. | 73.3 MB   | #########7 |  98%
# tensorflow-base-2.9. | 73.3 MB   | #########8 |  98%
# tensorflow-base-2.9. | 73.3 MB   | #########9 |  99%
# tensorflow-base-2.9. | 73.3 MB   | #########9 | 100%
# tensorflow-base-2.9. | 73.3 MB   | ########## | 100%
#
# google-auth-2.6.0    | 83 KB     |            |   0%
# google-auth-2.6.0    | 83 KB     | ########## | 100%
# google-auth-2.6.0    | 83 KB     | ########## | 100%
#
# scipy-1.7.3          | 13.9 MB   |            |   0%
# scipy-1.7.3          | 13.9 MB   | 2          |   2%
# scipy-1.7.3          | 13.9 MB   | 5          |   6%
# scipy-1.7.3          | 13.9 MB   | 9          |  10%
# scipy-1.7.3          | 13.9 MB   | #2         |  13%
# scipy-1.7.3          | 13.9 MB   | #6         |  17%
# scipy-1.7.3          | 13.9 MB   | ##         |  20%
# scipy-1.7.3          | 13.9 MB   | ##3        |  24%
# scipy-1.7.3          | 13.9 MB   | ##7        |  28%
# scipy-1.7.3          | 13.9 MB   | ###        |  31%
# scipy-1.7.3          | 13.9 MB   | ###4       |  34%
# scipy-1.7.3          | 13.9 MB   | ###7       |  38%
# scipy-1.7.3          | 13.9 MB   | ####1      |  41%
# scipy-1.7.3          | 13.9 MB   | ####5      |  45%
# scipy-1.7.3          | 13.9 MB   | ####8      |  48%
# scipy-1.7.3          | 13.9 MB   | #####2     |  53%
# scipy-1.7.3          | 13.9 MB   | #####6     |  56%
# scipy-1.7.3          | 13.9 MB   | #####9     |  59%
# scipy-1.7.3          | 13.9 MB   | ######2    |  63%
# scipy-1.7.3          | 13.9 MB   | ######5    |  66%
# scipy-1.7.3          | 13.9 MB   | ######9    |  69%
# scipy-1.7.3          | 13.9 MB   | #######2   |  73%
# scipy-1.7.3          | 13.9 MB   | #######5   |  76%
# scipy-1.7.3          | 13.9 MB   | #######9   |  79%
# scipy-1.7.3          | 13.9 MB   | ########2  |  83%
# scipy-1.7.3          | 13.9 MB   | ########6  |  86%
# scipy-1.7.3          | 13.9 MB   | #########  |  90%
# scipy-1.7.3          | 13.9 MB   | #########3 |  94%
# scipy-1.7.3          | 13.9 MB   | #########7 |  97%
# scipy-1.7.3          | 13.9 MB   | ########## | 100%
#
# termcolor-1.1.0      | 9 KB      |            |   0%
# termcolor-1.1.0      | 9 KB      | ########## | 100%
#
# certifi-2022.9.24    | 154 KB    |            |   0%
# certifi-2022.9.24    | 154 KB    | ########## | 100%
#
# cachetools-4.2.2     | 13 KB     |            |   0%
# cachetools-4.2.2     | 13 KB     | ########## | 100%
# cachetools-4.2.2     | 13 KB     | ########## | 100%
#
# yarl-1.8.1           | 80 KB     |            |   0%
# yarl-1.8.1           | 80 KB     | ########## | 100%
#
# absl-py-1.3.0        | 171 KB    |            |   0%
# absl-py-1.3.0        | 171 KB    | ########## | 100%
# absl-py-1.3.0        | 171 KB    | ########## | 100%
#
# oauthlib-3.2.1       | 194 KB    |            |   0%
# oauthlib-3.2.1       | 194 KB    | ########## | 100%
# oauthlib-3.2.1       | 194 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)

# %%
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
x_train=train_datagen.flow_from_directory(r'C:\Users\HARIHARAN\PycharmProjects\AI Analyzer for fitness enthusiasts\TRAIN_SET',target_size=(64, 64),batch_size=5,color_mode='rgb',class_mode='sparse')
# Out:
# Found 2626 images belonging to 5 classes.

# %%
x_test=test_datagen.flow_from_directory(r'C:\Users\HARIHARAN\PycharmProjects\AI Analyzer for fitness enthusiasts\TEST_SET',target_size=(64, 64),batch_size=5,color_mode='rgb',class_mode='sparse')
# Out:
# Found 1055 images belonging to 5 classes.

# %%
print(x_train.class_indices)
# Out:
# {'APPLES': 0, 'BANANA': 1, 'ORANGE': 2, 'PINEAPPLE': 3, 'WATERMELON': 4}

# %%
print(x_test.class_indices)
# Out:
# {'APPLES': 0, 'BANANA': 1, 'ORANGE': 2, 'PINEAPPLE': 3, 'WATERMELON': 4}

# %%
from collections import Counter as c
c(x_train.labels)
# Out:
# Counter({0: 606, 1: 445, 2: 479, 3: 621, 4: 475})

# %%
import numpy as np

# %%
import tensorflow

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras import layers

# %%
from tensorflow.keras.layers import Dense,Flatten

# %%
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dropout

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
model=Sequential()

# %%
classifier=Sequential()

# %%
classifier.add(Conv2D(32, (3, 3), input_shape=(64, 64 ,3), activation='relu'))

# %%
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# %%
classifier.add(Conv2D(32, (3, 3), activation='relu'))

# %%
classifier.add(Flatten())

# %%
classifier.add(Dense(units=128, activation='relu'))

# %%
classifier.add(Dense(units=5, activation='softmax'))

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  flatten (Flatten)           (None, 26912)             0
#
#  flatten_1 (Flatten)         (None, 26912)             0
#
#  flatten_2 (Flatten)         (None, 26912)             0
#
#  flatten_3 (Flatten)         (None, 26912)             0
#
#  dense (Dense)               (None, 128)               3444864
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,455,653
# Trainable params: 3,455,653
# Non-trainable params: 0
# _________________________________________________________________
